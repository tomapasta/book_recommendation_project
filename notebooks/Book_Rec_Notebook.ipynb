# %% [markdown]
# ****Project Brief****
# Problem: Choice Overload. Users waste more time searching than reading because of decision paralysis and a "winner-takes-all" market.
# Solution: A context-aware engine that replaces popularity bias with situational matching (mood, time, environment e.g. bedtime, 10mins, long holiday/travelling).
# Goal: Reduce decision fatigue and unlock the "Long Tail" of publishing/giving niche books the spotlight while helping readers find the perfect book for their current moment.

# %% [markdown]
# ****Goodreads Webscraping****
# Book data required
# - Genre
# - Title
# - Author
# - Rating
# - Rating counts
# - Description
# - Page numbers
# - ISBN
# - Language
# - Published Year
# - Book Cover Image
# - Link to the book

# %% [markdown]
# ****Open Library API***
# Identifiers: ISBN-13
# Physical Specs: Number of pages, physical dimensions, weight, and binding type (Hardcover, mass-market paperback, etc.).
#
# Publishing Info: Publisher name, specific publication date, and series name.
#
# Table of Contents: Often includes a full list of chapters (a feature many other APIs lack).
#
# 3. The "Author" Layer
# Open Library treats authors as distinct entities with their own metadata.
#
# Biographical Data: Full name, birth/death dates, and a biography.
#
# Identifiers: Links to external authority files like VIAF, Wikidata, and Library of Congress ID.
#
# Photos: Portraits of the author when available.
#
# 4. Digital & Community Data
# Because Open Library is part of the Internet Archive, it includes unique "living" data:
#
# Availability: Data on whether an eBook version is available to borrow, read online, or download.
#
# Community Activity: User-generated Reading Logs (Want to Read, Currently Reading, Have Read), public Book Lists, and user ratings.
#
# Revision History: Every single change made to a record is stored, meaning you can access previous "versions" of a book's data.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time

# %%
#Checking if the webscraping works 
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36'}
r = requests.get("https://www.goodreads.com/", headers=headers)
print (r.status_code)
# Out:
# 200

# %% [markdown]
# soup = BeautifulSoup(r.text, 'html.parser' )
# print (soup.prettify())

# %%
#create the dictionary of genre list 
genres_list = {}
for a in soup.select("div a.gr-hyperlink href=genres/art"):

# %%
genre_art = []

for a in soup.select('a.gr-hyperlink[href="/genres/art"]'):
    text = a.get_text(strip=True)
    
    if text:
        genre_art.append(text)

print(genre_art)
# Out:
# ['Art']

# %% [markdown]
# #genre_art = []
# #----------------------------
# #for a in soup.select('a.gr-hyperlink[href="/genres/art"]'):
# #text = a.get_text(strip=True)
# #if text:
#    #     genre_art.append(text)
#
# #print(genre_art)

# %%
#Best Book Ever List from GoodReads 
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36'}
r = requests.get("https://www.goodreads.com/list/show/1.Best_Books_Ever", headers=headers)
print (r.status_code)
# Out:
# 200

# %%
#Prettyfing the Best Book Ever Page 
soup = BeautifulSoup(r.text, 'html.parser' ) 
#print (soup.prettify())

# %%
#Best Book Ever List from GoodReads 
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36'}
r = requests.get("https://www.goodreads.com/book/show/2767052-the-hunger-games", headers=headers)
print (r.status_code)
# Out:
# 200

# %%
#Prettifying Hanger Games  
soup = BeautifulSoup(r.text, 'html.parser' ) 
#print (soup.prettify())

# %%
#Testing to see if we can scrape the title only, it did not return result 
results_list = [] 
for a in soup.select('h1.Text_title1'):
    text = a.get_text(strip=True)

    results_list.append(text)

print(results_list)

# %%
#Web Scraping of Best Book Ever List 
# Base URL for the list
the_hunger_game = {}

base_url = "https://www.goodreads.com/list/show/1.Best_Books_Ever"
page_to_scrape = 1  # Starting page

def scrape_book_details(book_url):
    # This simulates "clicking" into the book
    full_url = "https://www.goodreads.com" + book_url
    response = requests.get(full_url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    #Title 
    title = soup.find('h1', {'class': 'Text Text_title1'}) #this was the wrong position 
    return title.text.strip() if title else "No title"

# Pagination Loop
while page_to_scrape <= 2:  # Let's just do 2 pages for this example
    print(f"--- Scraping Page {page_to_scrape} ---")
    params = {'page': page_to_scrape}
    response = requests.get(base_url, params=params)
    soup = BeautifulSoup(response.text, 'html.parser')

    # 1. Find all book links on the list page
    book_links = soup.find_all('a', class_='bookTitle')

    for link in book_links:
        relative_url = link['href']
        title = link.find('span').text
        print(f"Clicking into: {title}")
        
        # 2. Go inside the book page
        desc = scrape_book_details(relative_url)
        print(f"Description found: {desc[:50]}...")
        
        # Respectful delay so you don't get banned
        all_books.append(the_hunger_game)
        time.sleep(1)

    page_to_scrape += 1

the_hunger_game
# Out:
# --- Scraping Page 1 ---
# --- Scraping Page 2 ---
# {}

# %%
#1000 Fiction Books from Open Library API 
import requests
import pandas as pd
import time

open_lib = []
target_count = 600
page = 1

#putting all the column names, so to avoid empty cells (only return the data when its not empty) 
fields = "title,author_name,subject,ratings_average,ratings_count,first_sentence,number_of_pages_median,isbn,language,first_publish_year,cover_i,key"

print("starting Data Collection...")

while len(open_lib) < target_count:
    url = f"https://openlibrary.org/search.json?subject=fiction&fields={fields}&page={page}&limit=1000" #genre is fiction here
    
    headers = {'User-Agent': 'bookrecommendation/1.0 (example@email.com)'} #this gives an user agent to make the access clear its human 
    
    try:
        response = requests.get(url, headers=headers, timeout=10) #if there is not response in 10seconds, show connection error 
    except requests.exceptions.RequestException as e: 
        print(f"❌ Connection error: {e}")
        break

    if response.status_code == 200: #if status code is 200, proceed 
        json_response = response.json()
        data = json_response.get('docs', []) #'docs' is where the book list is : "Each document specified listed in "docs"
        
        if not data:
            print("No more data available.")
            break

        for item in data:
            if len(open_lib) >= target_count:
                break

            # 2. Extracting data with safe defaults
            # Note: first_sentence is often a list, so we handle that specifically
            desc = item.get('first_sentence')
            description = desc[0] if isinstance(desc, list) else "No description available"

            row = {
                'Title': item.get('title'),
                'Author': item.get('author_name', ['N/A'])[0], #"Get the list of authors. If there are none, use ['N/A']. Then, just take the 1st one ([0])."
                'Genre': ", ".join(item.get('subject', [])[:3]), #Subjects are also lists. This takes the first 3 items ([:3]) unified with a comma.
                'Rating_Average': item.get('ratings_average'),
                'Rating_Counts': item.get('ratings_count'),
                'Description': description,
                'Page_Numbers': item.get('number_of_pages_median'), #OP has median of all versions e.g. hard/paper cover 
                'ISBN': item.get('isbn', ['N/A'])[0],
                'Language': item.get('language', ['N/A'])[0],
                'Published_Year': item.get('first_publish_year'),
                'Cover_URL': f"https://covers.openlibrary.org/b/id/{item.get('cover_i')}-L.jpg" if item.get('cover_i') else None,
                'Book_Link': f"https://openlibrary.org{item.get('key')}"
            }
        
            open_lib.append(row) #appending retrieved data to the list 
        
        print(f"Page {page} processed. Total items collected: {len(open_lib)}") #number of page collected 
        page += 1 #increment the page one by one 
        time.sleep(1) #sleep for 1 sec per page loading 
        
    elif response.status_code == 429: #if there is some distruption, wait for 20secs 
        print("Waiting 20 seconds...")
        time.sleep(20)
    else:
        print(f"❌ Error {response.status_code}. Stopping.")
        break

#converting to dataframe
op_fic_df = pd.DataFrame(open_lib)

op_fic_df.dropna(subset=['Title'], inplace=True) #if title does not exist, drop 

print("Collection Complete!")

op_fic_df.to_csv('Open_Library_Fiction_1000.csv', index=False)
# Out:
# starting Data Collection...
# Page 1 processed. Total items collected: 600
# Collection Complete!

# %%
op_fic_df.head(10)
# Out:
#                           Title                        Author  \
# 0                 The Iron Heel                   Jack London
# 1                        Игрокъ  Фёдор Михайлович Достоевский
# 2      Brood of the Witch-Queen                    Sax Rohmer
# 3  The Napoleon of Notting Hill      Gilbert Keith Chesterton
# 4             Emily of New Moon          Lucy Maud Montgomery
# 5                   The Vampyre         John William Polidori
# 6               The Sea Fairies                 L. Frank Baum
# 7                        Lilith              George MacDonald
# 8          The Enchanted Castle                  Edith Nesbit
# 9                     Pollyanna        Eleanor Hodgman Porter
#
#                                                Genre  Rating_Average  \
# 0  Revolutions, fiction, Oligarchy, fiction, Utop...        3.500000
# 1  Translations into English, Continental europea...        3.714286
# 2                           Fantasy, Fiction, Horror        4.600000
# 3       Fiction, Classic Literature, Science Fiction        4.571429
# 4           Juvenile fiction, Child authors, Orphans        3.666667
# 5                          Fiction, Incest, Vampires        3.583333
# 6  Children's stories, Juvenile fiction, Classic ...        3.333333
# 7  Fiction, romance, fantasy, Fiction, general, N...        3.200000
# 8                            Fiction, Fantasy, Magic        4.181818
# 9            Aunts, Cheerfulness, Classic Literature        3.809524
#
#    Rating_Counts                                        Description  \
# 0           20.0  THE SOFT summer wind stirs the redwood, and Wi...
# 1            7.0  At length I returned from two weeks leave of a...
# 2            5.0                           No description available
# 3            7.0                           No description available
# 4            9.0  The house in the hollow was "a mile from anywh...
# 5           12.0                           No description available
# 6            3.0  "Nobody," said Cap'n Bill solemnly, "ever sawr...
# 7            5.0  I had just finished my studies at Oxford, and ...
# 8           11.0  There were three of them-Jerry, Jimmy, and Kat...
# 9           21.0  Miss Polly Harrington entered her kitchen a li...
#
#    Page_Numbers           ISBN Language  Published_Year  \
# 0           287     1548921947      eng            1907
# 1           191  9798630153272      eng            1900
# 2           206     1985805111      eng            1924
# 3           160     1445508265      eng            1904
# 4           339     1548912425      eng            1923
# 5            55     1517322030      fre            1819
# 6           130  9781098604226      rus            1911
# 7           270     1406530042      fre            1895
# 8           186  9781548958534      spa            1907
# 9           194     1532762569      eng            1912
#
#                                            Cover_URL  \
# 0  https://covers.openlibrary.org/b/id/8243314-L.jpg
# 1  https://covers.openlibrary.org/b/id/3293339-L.jpg
# 2  https://covers.openlibrary.org/b/id/2011286-L.jpg
# 3  https://covers.openlibrary.org/b/id/6980094-L.jpg
# 4  https://covers.openlibrary.org/b/id/14638065-L...
# 5  https://covers.openlibrary.org/b/id/4871002-L.jpg
# 6  https://covers.openlibrary.org/b/id/1814237-L.jpg
# 7  https://covers.openlibrary.org/b/id/14364546-L...
# 8  https://covers.openlibrary.org/b/id/6644514-L.jpg
# 9   https://covers.openlibrary.org/b/id/902113-L.jpg
#
#                                   Book_Link
# 0    https://openlibrary.org/works/OL74502W
# 1   https://openlibrary.org/works/OL166923W
# 2  https://openlibrary.org/works/OL2288676W
# 3    https://openlibrary.org/works/OL76473W
# 4    https://openlibrary.org/works/OL77781W
# 5  https://openlibrary.org/works/OL3625242W
# 6   https://openlibrary.org/works/OL262384W
# 7    https://openlibrary.org/works/OL15437W
# 8    https://openlibrary.org/works/OL99541W
# 9  https://openlibrary.org/works/OL2775807W

# %%
#history, biography, science, philosophy, religion, cookery - list of non-fictions 
op_nonfic = []
target_count = 100
page = 1

#putting all the column names, so to avoid empty cells (only return the data when its not empty) 
fields = "title,author_name,subject,ratings_average,ratings_count,first_sentence,number_of_pages_median,isbn,language,first_publish_year,cover_i,key"

print("starting Data Collection...")

while len(op_nonfic) < target_count:
    url = f"https://openlibrary.org/search.json?subject=history&fields={fields}&page={page}&limit=100" #genre is fiction here
    
    headers = {'User-Agent': 'bookrecommendation/1.0 (example@email.com)'} #this gives an user agent to make the access clear its human 
    
    try:
        response = requests.get(url, headers=headers, timeout=10) #if there is not response in 10seconds, show connection error 
    except requests.exceptions.RequestException as e: 
        print(f"❌ Connection error: {e}")
        break

    if response.status_code == 200: #if status code is 200, proceed 
        json_response = response.json()
        data = json_response.get('docs', []) #'docs' is where the book list is : "Each document specified listed in "docs"
        
        if not data:
            print("No more data available.")
            break

        for item in data:
            if len(op_nonfic) >= target_count:
                break

            # 2. Extracting data with safe defaults
            # Note: first_sentence is often a list, so we handle that specifically
            desc = item.get('first_sentence')
            description = desc[0] if isinstance(desc, list) else "No description available"

            row = {
                'Title': item.get('title'),
                'Author': item.get('author_name', ['N/A'])[0], #"Get the list of authors. If there are none, use ['N/A']. Then, just take the 1st one ([0])."
                'Genre': ", ".join(item.get('subject', [])[:3]), #Subjects are also lists. This takes the first 3 items ([:3]) unified with a comma.
                'Rating_Average': item.get('ratings_average'),
                'Rating_Counts': item.get('ratings_count'),
                'Description': description,
                'Page_Numbers': item.get('number_of_pages_median'), #OP has median of all versions e.g. hard/paper cover 
                'ISBN': item.get('isbn', ['N/A'])[0],
                'Language': item.get('language', ['N/A'])[0],
                'Published_Year': item.get('first_publish_year'),
                'Cover_URL': f"https://covers.openlibrary.org/b/id/{item.get('cover_i')}-L.jpg" if item.get('cover_i') else None,
                'Book_Link': f"https://openlibrary.org{item.get('key')}"
            }
        
            op_nonfic.append(row) #appending retrieved data to the list 
        
        print(f"Page {page} processed. Total items collected: {len(op_nonfic)}") #number of page collected 
        page += 1 #increment the page one by one 
        time.sleep(1) #sleep for 1 sec per page loading 
        
    elif response.status_code == 429: #if there is some distruption, wait for 20secs 
        print("Waiting 20 seconds...")
        time.sleep(20)
    else:
        print(f"❌ Error {response.status_code}. Stopping.")
        break

#converting to dataframe
op_hist_df = pd.DataFrame(op_nonfic)

op_hist_df.dropna(subset=['Title'], inplace=True) #if title does not exist, drop 

print("Collection Complete!")

op_hist_df.to_csv('Open_Library_History_600.csv', index=False)
# Out:
# starting Data Collection...
# Page 1 processed. Total items collected: 100
# Collection Complete!

# %%
op_hist_df
# Out:
#                       Title                        Author  \
# 0   The Story of Philosophy                   Will Durant
# 1      Записки изъ подполья  Фёдор Михайлович Достоевский
# 2       The Enduring Vision                 Paul S. Boyer
# 3       La conquête du pain               Peter Kropotkin
# 4        A Study of History             Arnold J. Toynbee
# ..                      ...                           ...
# 95            Paradise Lost                   John Milton
# 96     Five Children and It                  Edith Nesbit
# 97                  Othello           William Shakespeare
# 98                  Sonnets           William Shakespeare
# 99                  Rayuela                Julio Cortázar
#
#                                                 Genre  Rating_Average  \
# 0                   Philosophers, Philosophy, History        4.200000
# 1           Fiction, History, Officials and employees        4.250000
# 2          Textbooks, History, United states, history        4.625000
# 3                       History, Communism, Anarchism        4.071429
# 4                   Civilization, Philosophy, History        4.500000
# ..                                                ...             ...
# 95     Bible, Biography, Criticism and interpretation        3.828571
# 96                           Fiction, Fairies, Wishes        4.000000
# 97    Drama, Othello (Fictitious character), Printing        3.780488
# 98  English Sonnets, History and criticism, Biblio...        4.166666
# 99  Chronology, Social life and customs, Spanish f...        4.100000
#
#     Rating_Counts                                        Description  \
# 0            15.0  IF YOU look at a map of Europe you will observ...
# 1             4.0  The ellipsis after the opening sentence of Not...
# 2             8.0                           No description available
# 3            14.0   به شیوا\r\nو نارنج هزاردانهٔ آفتاب\r\n\r\nر. الف
# 4             8.0  HISTORIANS generally illustrate rather than co...
# ..            ...                                                ...
# 95           35.0  This first book proposes, first in brief, the ...
# 96            7.0  The house was three miles from the station, bu...
# 97           41.0  'Othello', in the words of Edward Pechter, 'ha...
# 98           12.0     From the fairest creatures we desire increase,
# 99           10.0                              WOULD I find La Maga?
#
#     Page_Numbers           ISBN Language  Published_Year  \
# 0            543     1512110353      urd            1926
# 1            130     1503055582      eng            1864
# 2            610  9780618218615      eng            1987
# 3            234     8897011268      ita            1892
# 4            576  9780192152190      eng            1900
# ..           ...            ...      ...             ...
# 95           333     0198319126      mal            1667
# 96           150     1306356903      eng            1905
# 97           180  9788495882226      jpn            1622
# 98           168  9789504359470      ukr            1609
# 99           633  9781548833152      tur            1963
#
#                                             Cover_URL  \
# 0    https://covers.openlibrary.org/b/id/405360-L.jpg
# 1   https://covers.openlibrary.org/b/id/12644033-L...
# 2   https://covers.openlibrary.org/b/id/8237922-L.jpg
# 3   https://covers.openlibrary.org/b/id/7296134-L.jpg
# 4    https://covers.openlibrary.org/b/id/121255-L.jpg
# ..                                                ...
# 95  https://covers.openlibrary.org/b/id/5992814-L.jpg
# 96    https://covers.openlibrary.org/b/id/28174-L.jpg
# 97  https://covers.openlibrary.org/b/id/7165018-L.jpg
# 98  https://covers.openlibrary.org/b/id/8222090-L.jpg
# 99  https://covers.openlibrary.org/b/id/1047466-L.jpg
#
#                                     Book_Link
# 0    https://openlibrary.org/works/OL1073898W
# 1   https://openlibrary.org/works/OL25571500W
# 2    https://openlibrary.org/works/OL2024851W
# 3    https://openlibrary.org/works/OL1105382W
# 4    https://openlibrary.org/works/OL1108523W
# ..                                        ...
# 95    https://openlibrary.org/works/OL810991W
# 96     https://openlibrary.org/works/OL99499W
# 97    https://openlibrary.org/works/OL258850W
# 98    https://openlibrary.org/works/OL362706W
# 99  https://openlibrary.org/works/OL14860424W
#
# [100 rows x 12 columns]

# %%
#biography 
op_bio = []
target_count = 400
page = 1

#putting all the column names, so to avoid empty cells (only return the data when its not empty) 
fields = "title,author_name,subject,ratings_average,ratings_count,first_sentence,number_of_pages_median,isbn,language,first_publish_year,cover_i,key"

print("starting Data Collection...")

while len(op_bio) < target_count:
    url = f"https://openlibrary.org/search.json?subject=biography&fields={fields}&page={page}&limit=400" #genre is fiction here
    
    headers = {'User-Agent': 'bookrecommendation/1.0 (example@email.com)'} #this gives an user agent to make the access clear its human 
    
    try:
        response = requests.get(url, headers=headers, timeout=10) #if there is not response in 10seconds, show connection error 
    except requests.exceptions.RequestException as e: 
        print(f"❌ Connection error: {e}")
        break

    if response.status_code == 200: #if status code is 200, proceed 
        json_response = response.json()
        data = json_response.get('docs', []) #'docs' is where the book list is : "Each document specified listed in "docs"
        
        if not data:
            print("No more data available.")
            break

        for item in data:
            if len(op_bio) >= target_count:
                break

            # 2. Extracting data with safe defaults
            # Note: first_sentence is often a list, so we handle that specifically
            desc = item.get('first_sentence')
            description = desc[0] if isinstance(desc, list) else "No description available"

            row = {
                'Title': item.get('title'),
                'Author': item.get('author_name', ['N/A'])[0], #"Get the list of authors. If there are none, use ['N/A']. Then, just take the 1st one ([0])."
                'Genre': ", ".join(item.get('subject', [])[:3]), #Subjects are also lists. This takes the first 3 items ([:3]) unified with a comma.
                'Rating_Average': item.get('ratings_average'),
                'Rating_Counts': item.get('ratings_count'),
                'Description': description,
                'Page_Numbers': item.get('number_of_pages_median'), #OP has median of all versions e.g. hard/paper cover 
                'isbn': item.get('isbn', ['N/A'])[0],
                'Language': item.get('language', ['N/A'])[0],
                'Published_Year': item.get('first_publish_year'),
                'Cover_URL': f"https://covers.openlibrary.org/b/id/{item.get('cover_i')}-L.jpg" if item.get('cover_i') else None,
                'Book_Link': f"https://openlibrary.org{item.get('key')}"
            }
        
            op_bio.append(row) #appending retrieved data to the list 
        
        print(f"Page {page} processed. Total items collected: {len(op_bio)}") #number of page collected 
        page += 1 #increment the page one by one 
        time.sleep(1) #sleep for 1 sec per page loading 
        
    elif response.status_code == 429: #if there is some distruption, wait for 20secs 
        print("Waiting 20 seconds...")
        time.sleep(20)
    else:
        print(f"❌ Error {response.status_code}. Stopping.")
        break

#converting to dataframe
op_bio_df = pd.DataFrame(op_bio)

op_bio_df.dropna(subset=['Title'], inplace=True) #if title does not exist, drop 

print("Collection Complete!")

op_bio_df.to_csv('Open_Library_Biography_400.csv', index=False)
# Out:
# starting Data Collection...
# Page 1 processed. Total items collected: 400
# Collection Complete!

# %%
op_bio_df
# Out:
#                                                  Title                 Author  \
# 0    The life of Olaudah Equiano, or Gustavus Vassa...        Olaudah Equiano
# 1                              Autobiography of a Yogi  Yogananda Paramahansa
# 2                                                Lives               Plutarch
# 3          Narrative of the life of Frederick Douglass     Frederick Douglass
# 4                                      Les confessions  Jean-Jacques Rousseau
# ..                                                 ...                    ...
# 395                                     Zlatin dnevnik       Zlata Filipović
# 396                       The Journals of Sylvia Plath             Ted Hughes
# 397                               Lady sings the blues         Billie Holiday
# 398                                   Small sacrifices               Ann Rule
# 399                         Mountains Beyond Mountains           Tracy Kidder
#
#                                                  Genre  Rating_Average  \
# 0    Slavery, Voyages and travels, Social life and ...        4.000000
# 1                           Autobiography, Yogis, Yoga        4.186047
# 2    Biography, Classical biography, Early works to...        3.375000
# 3    Douglass, frederick, 1818-1895, Biography, Afr...        4.333334
# 4            French Authors, Biography, Correspondence        4.500000
# ..                                                 ...             ...
# 395  Children and war, Diaries, Bosnian Personal na...        5.000000
# 396                 American Poets, Biography, Diaries             NaN
# 397   Jazz, Zangeressen, Correspondence, reminiscences        4.333334
# 398              Murder, Trials (Murder), Case studies        4.400000
# 399                     Poor, Physicians, Human rights        4.300000
#
#      Rating_Counts                                        Description  \
# 0              5.0  PERMIT me with the greatest deference and resp...
# 1             43.0  THE CHARACTERISTIC FEATURES of Indian culture ...
# 2              8.0  As geographers, Sosius, crowd into the edges o...
# 3             12.0  Frederick Douglass was the most important Afri...
# 4              4.0                           No description available
# ..             ...                                                ...
# 395            1.0  Behind me-a long, hot summer and the happy day...
# 396            NaN                           No description available
# 397            3.0                           No description available
# 398           10.0  gency room doctor; his assessment of patient's...
# 399           10.0  Six years after the fact, Dr. Paul Edward Farm...
#
#      Page_Numbers           ISBN Language  Published_Year  \
# 0             241     1528705653      eng            1789
# 1             514  9781565897342      eng            1946
# 2             483  9780375756764      grc            1564
# 3             127  9798698409281      und            1845
# 4             606     034180844X      eng            1782
# ..            ...            ...      ...             ...
# 395           200     9578829086      chi            1993
# 396           370     3492227783      eng            1982
# 397           203     0380004917      eng            1956
# 398           494     0751535567      eng            1987
# 399           332     8494645331      spa            2003
#
#                                              Cover_URL  \
# 0    https://covers.openlibrary.org/b/id/2074044-L.jpg
# 1     https://covers.openlibrary.org/b/id/805448-L.jpg
# 2    https://covers.openlibrary.org/b/id/10679669-L...
# 3    https://covers.openlibrary.org/b/id/8247724-L.jpg
# 4    https://covers.openlibrary.org/b/id/6371045-L.jpg
# ..                                                 ...
# 395  https://covers.openlibrary.org/b/id/3899848-L.jpg
# 396  https://covers.openlibrary.org/b/id/8222248-L.jpg
# 397    https://covers.openlibrary.org/b/id/93864-L.jpg
# 398   https://covers.openlibrary.org/b/id/291624-L.jpg
# 399   https://covers.openlibrary.org/b/id/606360-L.jpg
#
#                                     Book_Link
# 0     https://openlibrary.org/works/OL743333W
# 1     https://openlibrary.org/works/OL528094W
# 2    https://openlibrary.org/works/OL2521179W
# 3      https://openlibrary.org/works/OL69178W
# 4      https://openlibrary.org/works/OL80592W
# ..                                        ...
# 395  https://openlibrary.org/works/OL3029795W
# 396  https://openlibrary.org/works/OL1865540W
# 397  https://openlibrary.org/works/OL5603902W
# 398   https://openlibrary.org/works/OL892130W
# 399    https://openlibrary.org/works/OL98216W
#
# [400 rows x 12 columns]

# %%
gr_df = pd.read_csv ('../data/processed/goodreads_books.csv')
gr_df.info()
gr_df['isbn']= gr_df['isbn'].astype(int),coerce=error 
gr_df.c
#op_bio_df
#op_hist_df
#op_fic_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            499 non-null    object
#  1   author           499 non-null    object
#  2   rating           499 non-null    float64
#  3   rating_count     499 non-null    float64
#  4   description      0 non-null      float64
#  5   isbn             378 non-null    float64
#  6   image            498 non-null    object
#  7   url_from_jsonld  0 non-null      float64
#  8   book_url         500 non-null    object
#  9   pages            499 non-null    float64
#  10  published_year   0 non-null      float64
#  11  language         0 non-null      float64
#  12  genres           499 non-null    object
# dtypes: float64(8), object(5)
# memory usage: 50.9+ KB
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 3
#       1 gr_df = pd.read_csv ('../data/processed/goodreads_books.csv')
#       2 gr_df.info()
# ----> 3 gr_df['isbn']= gr_df['isbn'].str.upper()
#       4 #op_bio_df
#       5 #op_hist_df
#       6 #op_fic_df
#
# File ~\miniconda3\envs\data_env\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File ~\miniconda3\envs\data_env\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\miniconda3\envs\data_env\Lib\site-packages\pandas\core\strings\accessor.py:194, in StringMethods.__init__(self, data)
#     191 def __init__(self, data) -> None:
#     192     from pandas.core.arrays.string_ import StringDtype
# --> 194     self._inferred_dtype = self._validate(data)
#     195     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     196     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\miniconda3\envs\data_env\Lib\site-packages\pandas\core\strings\accessor.py:248, in StringMethods._validate(data)
#     245 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     247 if inferred_dtype not in allowed_types:
# --> 248     raise AttributeError("Can only use .str accessor with string values!")
#     249 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
#Standardising Columns to lower cases 
op_bio_df.columns = op_bio_df.columns.str.lower()
gr_df.columns = gr_df.columns.str.lower()
op_hist_df.columns = op_hist_df.columns.str.lower()
op_fic_df.columns = op_fic_df.columns.str.lower()

# %%
gr_df['isbn'] = gr_df['isbn'].astype('object')
op_bio_df['isbn'] = op_bio_df['isbn'].astype('object')
op_hist_df['isbn'] = op_hist_df['isbn'].astype('object')
op_fic_df['isbn'] = op_fic_df['isbn'].astype('object')

# %%
first_df = gr_df.merge(op_bio_df, on = 'isbn', how = 'left')
first_df
# Out:
#                                                title_x         author_x  \
# 0              The Hunger Games (The Hunger Games, #1)  Suzanne Collins
# 1                                  Pride and Prejudice      Jane Austen
# 2                                To Kill a Mockingbird       Harper Lee
# 3    Harry Potter and the Order of the Phoenix (Har...     J.K. Rowling
# 4                                       The Book Thief     Markus Zusak
# ..                                                 ...              ...
# 495                            Stargirl (Stargirl, #1)   Jerry Spinelli
# 496                                           Coraline      Neil Gaiman
# 497      The Amazing Adventures of Kavalier &amp; Clay   Michael Chabon
# 498        The Amber Spyglass (His Dark Materials, #3)   Philip Pullman
# 499  City of Heavenly Fire (The Mortal Instruments,...  Cassandra Clare
#
#      rating  rating_count  description_x           isbn  \
# 0      4.35     9943135.0            NaN  9780439023481
# 1      4.30     4821169.0            NaN  9781441341709
# 2      4.26     6905680.0            NaN  9780060935467
# 3      4.50     3805184.0            NaN  9780439358064
# 4      4.39     2887607.0            NaN           <NA>
# ..      ...           ...            ...            ...
# 495    3.77      336518.0            NaN  9780439488402
# 496    4.13      784166.0            NaN  9780061139376
# 497    4.19      213129.0            NaN  9780312282998
# 498    4.11      384242.0            NaN  9780440238157
# 499    4.38      416442.0            NaN  9781481426305
#
#                                                  image  url_from_jsonld  \
# 0    https://m.media-amazon.com/images/S/compressed...              NaN
# 1    https://m.media-amazon.com/images/S/compressed...              NaN
# 2    https://m.media-amazon.com/images/S/compressed...              NaN
# 3    https://m.media-amazon.com/images/S/compressed...              NaN
# 4    https://m.media-amazon.com/images/S/compressed...              NaN
# ..                                                 ...              ...
# 495  https://m.media-amazon.com/images/S/compressed...              NaN
# 496  https://m.media-amazon.com/images/S/compressed...              NaN
# 497  https://m.media-amazon.com/images/S/compressed...              NaN
# 498  https://m.media-amazon.com/images/S/compressed...              NaN
# 499  https://m.media-amazon.com/images/S/compressed...              NaN
#
#                                               book_url  pages  ...  author_y  \
# 0    https://www.goodreads.com/book/show/2767052-th...  374.0  ...       NaN
# 1    https://www.goodreads.com/book/show/1885.Pride...  279.0  ...       NaN
# 2    https://www.goodreads.com/book/show/2657.To_Ki...  323.0  ...       NaN
# 3    https://www.goodreads.com/book/show/58613451-h...  896.0  ...       NaN
# 4    https://www.goodreads.com/book/show/19063.The_...  592.0  ...       NaN
# ..                                                 ...    ...  ...       ...
# 495  https://www.goodreads.com/book/show/22232.Star...  186.0  ...       NaN
# 496  https://www.goodreads.com/book/show/17061.Cora...  208.0  ...       NaN
# 497  https://www.goodreads.com/book/show/3985.The_A...  639.0  ...       NaN
# 498  https://www.goodreads.com/book/show/18122.The_...  465.0  ...       NaN
# 499  https://www.goodreads.com/book/show/8755785-ci...  725.0  ...       NaN
#
#      genre rating_average rating_counts description_y page_numbers  \
# 0      NaN            NaN           NaN           NaN          NaN
# 1      NaN            NaN           NaN           NaN          NaN
# 2      NaN            NaN           NaN           NaN          NaN
# 3      NaN            NaN           NaN           NaN          NaN
# 4      NaN            NaN           NaN           NaN          NaN
# ..     ...            ...           ...           ...          ...
# 495    NaN            NaN           NaN           NaN          NaN
# 496    NaN            NaN           NaN           NaN          NaN
# 497    NaN            NaN           NaN           NaN          NaN
# 498    NaN            NaN           NaN           NaN          NaN
# 499    NaN            NaN           NaN           NaN          NaN
#
#      language_y  published_year_y cover_url  book_link
# 0           NaN               NaN       NaN        NaN
# 1           NaN               NaN       NaN        NaN
# 2           NaN               NaN       NaN        NaN
# 3           NaN               NaN       NaN        NaN
# 4           NaN               NaN       NaN        NaN
# ..          ...               ...       ...        ...
# 495         NaN               NaN       NaN        NaN
# 496         NaN               NaN       NaN        NaN
# 497         NaN               NaN       NaN        NaN
# 498         NaN               NaN       NaN        NaN
# 499         NaN               NaN       NaN        NaN
#
# [500 rows x 24 columns]
