# %% [markdown]
# **Reminder: don’t “run Streamlit” inside Jupyter but in the Terminal --> streamlit run app.py**

# %%
# location of streamlit library must be in the project folder i am working on 
# create a new environment or use a previous one that has already all the libraries
# in the Terminal: uv add streamlit / pip install ipykernel
# in Jupyter notebook : !pip install streamlit 

import sys
sys.executable  # sanity check
# Out:
# '/Users/chiara/Ironhack/week10/book_recommendation_project/.venv/bin/python'

# %%
# Terminal installment: uv add streamlit

# !pip install streamlit --upgrade  # version 1.54

# %%
import streamlit as st
import pandas as pd

st.set_page_config(page_title="Mood Book Recommender", layout="wide")
# Out:
# 2026-02-10 18:33:08.124 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import sys
print(sys.executable)
# Out:
# /Users/chiara/Ironhack/week10/book_recommendation_project/.venv/bin/python

# %%
def load_data():
    df = pd.read_csv("../data/processed/df_final_scored_with_descriptions.csv")
    print(df.head())
    return df

df = load_data()
# Out:
#                                                title           author  rating  \
# 0            The Hunger Games (The Hunger Games, #1)  Suzanne Collins    4.35
# 1                                Pride and Prejudice      Jane Austen    4.30
# 2                              To Kill a Mockingbird       Harper Lee    4.26
# 3  Harry Potter and the Order of the Phoenix (Har...     J.K. Rowling    4.50
# 4                                     The Book Thief     Markus Zusak    4.39
#
#    rating_count                                        description  \
# 0     9943135.0  Winning means fame and fortune. Losing means c...
# 1     4821169.0  Since its immediate success in 1813, Pride and...
# 2     6905680.0  "Shoot all the bluejays you want, if you can h...
# 3     3805184.0  It's official: the evil Lord Voldemort has ret...
# 4     2887607.0  Librarian's note: An alternate cover edition c...
#
#               isbn                                              image  \
# ...

# %%
MOOD_TO_TAGS = {
    "bedtime": ["emotional", "romantic", "fantasy"],
    "beach": ["easy-read", "light", "travel", "nature", "emotional";"romantic"],
    "easy": ["easy-read", "short", "fast-paced"],
    "on_the_go": ["fast-paced", "suspenseful", "travel", "nature"],
    "Inspirational": ["inspirational", "motivational", "self-discovery", "growth"],
}
